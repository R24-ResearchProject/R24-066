# %%
# !nvidia-smi
# Out:
# Sun Sep  8 17:21:45 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 527.56       Driver Version: 527.56       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   62C    P5     4W /  60W |    311MiB /  4096MiB |     34%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.1 torch-2.3.1+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# Setup complete ✅ (20 CPUs, 15.7 GB RAM, 443.1/453.2 GB disk)

# %%
cd Dataset
# Out:
# c:\Users\cheha\OneDrive\Desktop\V8-OBJ\Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ctxIvsGLU5FnLL0k3jY5")
project = rf.workspace("research-0jrw7").project("defect-detection-2md6s")
version = project.version(2)
dataset = version.download("folder")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Defect-detection-2 in folder:: 100%|██████████| 713/713 [00:06<00:00, 116.09it/s]

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\cheha\OneDrive\Desktop\V8-OBJ\Dataset

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.1 torch-2.3.1+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# Setup complete ✅ (20 CPUs, 15.7 GB RAM, 443.1/453.2 GB disk)

# %%
DATA_DIR = 'C:\\Users\\cheha\\OneDrive\\Desktop\\V8-OBJ\\Dataset'

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=classify mode=val model='/content/drive/MyDrive/Yv8 New/runs/classify/train3/weights/best.pt' data='{DATA_DIR}'
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15,766,499 parameters, 0 gradients, 41.6 GFLOPs
# train: /content/drive/MyDrive/Yv8 New/Dataset/train... found 488 images in 3 classes ✅
# val: /content/drive/MyDrive/Yv8 New/Dataset/val... found 141 images in 3 classes ✅
# test: /content/drive/MyDrive/Yv8 New/Dataset/test... found 68 images in 3 classes ✅
# val: Scanning /content/drive/MyDrive/Yv8 New/Dataset/val... 141 images, 0 corrupt: 100% 141/141 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100% 9/9 [00:03<00:00,  2.70it/s]
#                    all      0.965          1
# Speed: 0.1ms preprocess, 3.2ms inference, 0.1ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
Image(filename=f'/content/drive/MyDrive/Yv8 New/runs/classify/val/confusion_matrix.png')

# %%
Image(filename=f'/content/drive/MyDrive/Yv8 New/runs/classify/val/confusion_matrix_normalized.png')

# %%
# !yolo task=classify mode=predict model= '/content/drive/MyDrive/Yv8 New/runs/classify/train3/weights/best.pt' conf=0.5 source="/content/drive/MyDrive/Yv8 New/Dataset/test/High-Low/2024_04_02_11_31_IMG_8863_JPG.rf.210c67022a20ec775e77afacf10a9e38.jpg"
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15,766,499 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Yv8 New/Dataset/test/High-Low/2024_04_02_11_31_IMG_8863_JPG.rf.210c67022a20ec775e77afacf10a9e38.jpg: 128x128 Open-Seam 1.00, High-Low 0.00, Non-Defects 0.00, 5.4ms
# Speed: 19.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/drive/MyDrive/Yv8 New/runs/classify/predict*.jpg')[:10]:
      display(Image(filename=image_path, height=600))
      print("\n")

# %%
# !yolo task=classify mode=predict model= 'Dataset/runs/classify/train3/weights/best.pt' conf=0.5 source="Test1.mp4"
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\cheha\AppData\Local\Programs\Python\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "c:\Users\cheha\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\cfg\__init__.py", line 567, in entrypoint
#     model = YOLOv10(model)
#             ^^^^^^^^^^^^^^
#   File "c:\Users\cheha\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\models\yolov10\model.py", line 14, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "c:\Users\cheha\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py", line 141, in __init__
#     self._load(model, task=task)
#   File "c:\Users\cheha\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py", line 230, in _load
# ...
